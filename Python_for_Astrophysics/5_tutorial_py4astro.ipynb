# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariannly/ISYA2025/blob/main/Python_for_Astrophysics/5_tutorial_py4astro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualisation of simulation data (Part I) - MV
#
# We will use 2 different tools that are widely used in the simulation community:
#
# - YT: particle or mesh-based simulation files.
#
# - H5PY: a library to data process HDF5 files
#
# ## 1. The YT tool: Turbulent cloud simulation (FLASH code)
#
# In this section we will look into YT examples.
#
# The package is here: https://yt-project.org

# %%
# !pip install yt
# Out:
# Collecting yt
#   Downloading yt-4.4.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Collecting cmyt>=1.1.2 (from yt)
#   Downloading cmyt-2.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting ewah-bool-utils>=1.2.0 (from yt)
#   Downloading ewah_bool_utils-1.3.0-cp311-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from yt) (3.10.0)
# Requirement already satisfied: more-itertools>=8.4 in /usr/local/lib/python3.11/dist-packages (from yt) (10.7.0)
# Requirement already satisfied: numpy<3,>=1.21.3 in /usr/local/lib/python3.11/dist-packages (from yt) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from yt) (24.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from yt) (11.2.1)
# Collecting tomli-w>=0.4.0 (from yt)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: tqdm>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from yt) (4.67.1)
# Collecting unyt>=2.9.2 (from yt)
#   Downloading unyt-3.0.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from yt) (4.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->yt) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->yt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->yt) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->yt) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->yt) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->yt) (2.9.0.post0)
# Requirement already satisfied: sympy>=1.7 in /usr/local/lib/python3.11/dist-packages (from unyt>=2.9.2->yt) (1.13.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->yt) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.7->unyt>=2.9.2->yt) (1.3.0)
# Downloading yt-4.4.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 47.7 MB/s eta 0:00:00
# Downloading cmyt-2.0.2-py3-none-any.whl (30 kB)
# Downloading ewah_bool_utils-1.3.0-cp311-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 74.2 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading unyt-3.0.4-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 9.7 MB/s eta 0:00:00
# Installing collected packages: tomli-w, ewah-bool-utils, unyt, cmyt, yt
# Successfully installed cmyt-2.0.2 ewah-bool-utils-1.3.0 tomli-w-1.2.0 unyt-3.0.4 yt-4.4.1

# %%
# Import yt
import yt
import matplotlib.pyplot as plt

# %%
ds = yt.load_sample("DensTurbMag")
# Out:
# /usr/local/lib/python3.11/dist-packages/yt/sample_data/api.py:150: UserWarning: Storage directory from yt config doesn't exist (currently set to '/does/not/exist'). Current working directory will be used instead.
#   warn(
# yt : [INFO     ] 2025-07-10 20:53:44,067 'DensTurbMag' is not available locally. Looking up online.
# yt : [INFO     ] 2025-07-10 20:53:44,069 Downloading from https://yt-project.org/data/DensTurbMag.tar.gz
# 100%|█████████████████████████████████████| 1.65M/1.65M [00:00<00:00, 1.41GB/s]
# yt : [INFO     ] 2025-07-10 20:53:44,775 Untaring downloaded file to '/content'
# yt : [INFO     ] 2025-07-10 20:53:46,132 Parameters: current_time              = 751000000000.0
# yt : [INFO     ] 2025-07-10 20:53:46,133 Parameters: domain_dimensions         = [8 8 8]
# yt : [INFO     ] 2025-07-10 20:53:46,142 Parameters: domain_left_edge          = [-2.e+18 -2.e+18 -2.e+18]
# yt : [INFO     ] 2025-07-10 20:53:46,143 Parameters: domain_right_edge         = [2.e+18 2.e+18 2.e+18]
# yt : [INFO     ] 2025-07-10 20:53:46,145 Parameters: cosmological_simulation   = 0

# %%
#ds.print_stats()

# %%
ds.field_list
# Out:
# [('flash', 'dens'),
#  ('flash', 'ener'),
#  ('flash', 'gpot'),
#  ('flash', 'pres'),
#  ('flash', 'temp'),
#  ('flash', 'velx'),
#  ('flash', 'vely'),
#  ('flash', 'velz')]

# %%
#ds.derived_field_list

# %% [markdown]
# ### Density map:

# %%
# Save the plot with a specified figure size
p = yt.SlicePlot(ds, "y", ("gas", "density"))

p.set_figure_size(3)

p.set_cmap(("gas", "density"), "viridis")

p.show()
# Out:
# yt : [INFO     ] 2025-07-10 20:53:48,037 xlim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:48,039 ylim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:48,045 xlim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:48,046 ylim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:48,052 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
# Save the plot with a specified figure size
p = yt.ProjectionPlot(ds, "y", ("gas", "density"))

p.set_figure_size(3)

p.set_cmap(("gas", "density"), "magma")

p.show()
# Out:
# yt : [INFO     ] 2025-07-10 20:53:50,993 Projection completed
# yt : [INFO     ] 2025-07-10 20:53:50,997 xlim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:51,001 ylim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:51,008 xlim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:51,011 ylim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:51,015 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ### Temperature map:

# %%
# Save the plot with a specified figure size
p = yt.SlicePlot(ds, "y", ("gas", "temperature"))

p.set_figure_size(3)

p.set_cmap(("gas", "temperature"), "magma")

p.show()
# Out:
# yt : [INFO     ] 2025-07-10 20:53:53,677 xlim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:53,680 ylim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:53,705 xlim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:53,707 ylim = -2000000000000000000.000000 2000000000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:53,712 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ### Zoom-in:

# %%
p.zoom(2.0)
p.annotate_velocity()
p.set_figure_size(3)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p = yt.SlicePlot(ds, "x", ("gas", "density"), center="max")
p.set_figure_size(3)
p.annotate_contour(("gas", "density"))
p.zoom(2.5)
# Out:
# yt : [INFO     ] 2025-07-10 20:53:57,537 max value is 4.90329e-20 at 187500000000000000.0000000000000000 -62500000000000000.0000000000000000 187500000000000000.0000000000000000
# yt : [INFO     ] 2025-07-10 20:53:57,555 xlim = -2062500000000000000.000000 1937500000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:57,556 ylim = -1812500000000000000.000000 2187500000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:57,564 xlim = -2062500000000000000.000000 1937500000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:57,568 ylim = -1812500000000000000.000000 2187500000000000000.000000
# yt : [INFO     ] 2025-07-10 20:53:57,571 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## 2. The H5PY library: Illustris 3 Simulation

# %% [markdown]
# ### Mount Gdrive:

# %%
# Import libraries
from google.colab import drive

# %%
# Mount Google Drive
print("Mounting Google Drive...")
drive.mount('/content/drive')
# Out:
# Mounting Google Drive...
# Mounted at /content/drive

# %% [markdown]
# ### Check where we are:

# %%
# %cd /content/drive/MyDrive/ISYA2025/
# !pwd
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ISYA2025/'
# /content
# /content

# %% [markdown]
# ### Create a directory to store the simulation file we will visualise:

# %%
# Create new directory
# !mkdir -p "simulations"

# Change into the target directory for downloading
# %cd simulations
# Out:
# /content/simulations

# %% [markdown]
# ### Grab file from the TNG project.
#
# We will use my API-key. If you wish to use TNG files for your research, you will need to request an account.

# %%
# We will use my API-key here
# !wget -nd -nc -nv -e robots=off -l 1 -r -A hdf5 --content-disposition \
    --header="API-Key: e18844091d27d10cc8f94982d0a1c405" \
    "http://www.tng-project.org/api/Illustris-3/files/groupcat-135/?format=api"

# To verify the download, you can list the files in the directory
# !ls
# Out:
# 2025-07-10 20:54:35 URL:https://www.tng-project.org/api/Illustris-3/files/groupcat-135/?format=api [8803/8803] -> "index.html?format=api.tmp" [1]
# 2025-07-10 20:54:36 URL:https://www.tng-project.org/ [14277/14277] -> "index.html.tmp" [1]
# 2025-07-10 20:54:36 URL:https://www.tng-project.org/about/ [37279/37279] -> "index.html.tmp" [1]
# 2025-07-10 20:54:36 URL:https://www.tng-project.org/people/ [13267/13267] -> "index.html.tmp" [1]
# 2025-07-10 20:54:37 URL:https://www.tng-project.org/results/ [716325/716325] -> "index.html.tmp" [1]
# 2025-07-10 20:54:37 URL:https://www.tng-project.org/media/ [59010/59010] -> "index.html.tmp" [1]
# 2025-07-10 20:54:38 URL:https://www.tng-project.org/data/ [45239/45239] -> "index.html.tmp" [1]
# 2025-07-10 20:54:38 URL:https://www.tng-project.org/explore/ [3989/3989] -> "index.html.tmp" [1]
# 2025-07-10 20:54:38 URL:https://www.tng-project.org/cluster/ [49734/49734] -> "index.html.tmp" [1]
# 2025-07-10 20:54:39 URL:https://www.tng-project.org/users/login/ [5473/5473] -> "index.html.tmp" [1]
# 2025-07-10 20:54:39 URL:https://www.tng-project.org/users/login/ [5473/5473] -> "index.html.tmp" [1]
# 2025-07-10 20:54:39 URL:https://www.tng-project.org/api/?format=api [23739/23739] -> "index.html?format=api.tmp" [1]
# 2025-07-10 20:54:39 URL:https://www.tng-project.org/api/Illustris-3/?format=api [12581/12581] -> "index.html?format=api.tmp" [1]
# 2025-07-10 20:54:40 URL:https://www.tng-project.org/api/Illustris-3/files/?format=api [54956/54956] -> "index.html?format=api.tmp" [1]
# 2025-07-10 20:54:40 URL:https://www.tng-project.org/api/Illustris-3/files/groupcat-135/?format=json [153/153] -> "index.html?format=json.tmp" [1]
# 2025-07-10 20:54:44 URL:https://data-eu.tng-project.org/file/groupcat/L75n455FP/135/0/?token=393b15e4503e83bdab0a [43787044/43787044] -> "groups_135.0.hdf5" [1]
# 2025-07-10 20:54:48 URL:https://data-eu.tng-project.org/file/groupcat/L75n455FP/135/1/?token=8e60696b69e13e43bb32 [43787744/43787744] -> "groups_135.1.hdf5" [1]
# FINISHED --2025-07-10 20:54:48--
# Total wall clock time: 14s
# Downloaded: 17 files, 85M in 6.9s (12.3 MB/s)
# groups_135.0.hdf5  groups_135.1.hdf5

# %% [markdown]
# ### Double check file is correctly saved:

# %%
# !pwd
# !ls -ltr
# Out:
# /content/simulations
# total 85528
# -rw-r--r-- 1 root root 43787044 Nov  5  2015 groups_135.0.hdf5
# -rw-r--r-- 1 root root 43787744 Nov  5  2015 groups_135.1.hdf5

# %% [markdown]
# ### Import H5PY, which is a library for handling HDF5 files.

# %%
# Importing libraries

import h5py
import matplotlib.pyplot as plt

# %%
# Empty list for subhalo positions
subhalo_coord = []

# I/O HDF5
with h5py.File("./groups_135.0.hdf5", 'r') as f:
    # Positions are typically in the 'Subhalo' group, 'SubhaloPos' dataset
    # Units are often in simulation box units (e.g., Mpc/h)
    subhalo_coord = f['Subhalo']['SubhaloPos'][:]

# %% [markdown]
# ### Check data:

# %%
# Check type
#print(type(subhalo_coord))

# The total number of subhalos per coordinate (x,y,z)
#print(subhalo_coord.shape)

# %% [markdown]
# ### Plotting with Matplotlib (2D projection):

# %%
# Create the map plot
plt.figure(figsize=(6,6))

plt.scatter(subhalo_coord[:, 0], subhalo_coord[:, 1], s=1, alpha=0.5, color='blue')

# Axes
plt.xlabel('X Position (Mpc/h)')
plt.ylabel('Y Position (Mpc/h)')

plt.grid(True, linestyle='--', alpha=0.4)

plt.show()

# %% [markdown]
# ### Plotting with Matplotlib (3D view):

# %%
# Extract X, Y, Z coordinates
x_coords = subhalo_coord[:, 0]
y_coords = subhalo_coord[:, 1]
z_coords = subhalo_coord[:, 2]

# Create a new figure and add a 3D subplot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the subhalo positions as a scatter plot
ax.scatter(x_coords, y_coords, z_coords, s=1, color='blue', alpha=0.3)

# Set labels for the axes
ax.set_xlabel('X Position')
ax.set_ylabel('Y Position')
ax.set_zlabel('Z Position')

# ax.view_init(elev=20, azim=45)

# Display the plot
plt.show()

# %% [markdown]
# ### Plotting with Matplotlib (interactive 3D view):

# %%
import plotly.graph_objects as go

# %%
# Create a 3D scatter plot trace
trace = go.Scatter3d(x=x_coords, y=y_coords, z=z_coords, mode='markers',\
                     marker=dict(size=1,color='blue',opacity=0.5))

# Create the figure using the trace
fig = go.Figure(data=[trace])

# Update the layout
fig.update_layout(scene=dict(xaxis_title='X Position',yaxis_title='Y Position',zaxis_title='Z Position'),\
                 margin=dict(l=0, r=0, b=0, t=40))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="094e87df-cf2f-429b-aea0-f00e4498ba22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("094e87df-cf2f-429b-aea0-f00e4498ba22")) {                    Plotly.newPlot(                        "094e87df-cf2f-429b-aea0-f00e4498ba22",                        [{"marker":{"color":"blue","opacity":0.5,"size":1},"mode":"markers","x":[900.4253,181.12039,826.9236,1492.1937,839.73096,267.40964,963.79517,1171.5802,74993.56,1632.5065,1368.0372,1065.2831,792.206,74936.94,446.65784,859.71954,1528.8313,405.09546,1259.6931,658.9915,998.92993,1028.7161,74636.484,408.30334,1664.1274,893.47754,808.2334,657.1138,482.5801,555.04266,1628.1312,913.1448,494.79413,74993.78,736.9367,825.90894,1056.0127,74833.18,1753.9915,585